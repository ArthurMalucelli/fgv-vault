# %% [markdown]
# ## Parte I: Tentar responder sem rodar o código
#
# ```
# Responda Verdadeiro ou Falso.
#
# a = [1, 2, 3, 4, 5]
# len(a) retorna 6
#
# Responda Verdadeiro ou Falso.
#
# a = [1, 2, 3, 4, 5]
# a[1] retorna 1
#
# Responda Verdadeiro ou Falso.
#
# a = [1, 2, 3, 4, 5]
# a[5] retorna 5
#
# Responda Verdadeiro ou Falso.
#
# a = [1, 2, 3, 4, 5]
# a[-4] retorna 1
#
# ```

# %% [markdown]
# ----
# ```
# a = ['Araçatuba']
#
# O comando len(a) terá como resposta:
# O comand len(a[0]) terá como resposta:
# ```

# %% [markdown]
# ____

# %% [markdown]
# ```
# a = ['Batman', 'Hulk', 'Thor', 'Aquaman']
#
# O código
#
# for i in range(len(a)):
#
#        print(a[i])
#
# terá como resposta:
# Batman
# Hulk
# Thor
# Aquaman
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```
# a = ['Batman', 'Hulk', 'Thor', 'Aquaman']
#
# O código
#
# for i in a:
#
#        print(len(i))
#
# terá como resposta:
# 6
# 4
# 4
# 7
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```
# a = ['Batman', 'Hulk', 'Thor', 'Aquaman']
#
# some a quantidade de caracteres de todos os elementos contidos em a
#
# s = 0
#
# for i in a:
#
#     s = s + len(i)
#
# print(s)
#
# R: 21
# ```

# %% [markdown]
# ----
# ```
# a = ['Batman', 'Hulk', 'Thor', 'Aquaman']
#
# O que faz o código:
#
# for i in a:
#
#        print(i)
#
# R:
# Batman
# Hulk
# Thor
# Aquaman
# ```

# %% [markdown]
# ____

# %% [markdown]
# Crie duas listas:
# * material_escritorio com: "caneta", "lápis" e "caderno"
# * material_limpeza com: "sabão" e "detergente"
#
# Em seguida crie uma terceira lista chamada compras_totais que seja a combinação das duas listas anteriores. Imprima a lista compras_totais.

# %% [markdown]
# Checar o tamanho da lista

# %% [markdown]
# 1. Criar uma lista compras_ordenada com os elementos de compras_totais, ordenados alfabeticamente
# 2. Modificar a lista compras_totais, para que seus elementos fiquem ordenados alfabeticamente

# %% [markdown]
# Rode o comando abaixo:
# ```
# compras_totais = material_escritorio + material_limpeza * 2
# ```
# e verifique a lista compras_totais
#
# Inadvertidamente, voce acabou incluindo duas vezes os materiais de limpeza. <br>
# Assim, remova os ítens "sabão" e "detergente" duplicados

# %% [markdown]
# ----

# %% [markdown]
# ## Parte II: rodando o codigo para responder as questões

# %% [markdown]
# Rodar o codigo abaixo para carregar uma lista com os preços de fechamento diários de BITCOIN em USD.

# %%
import numpy as np
import pandas as pd
url = "https://github.com/hitoshinagano/data/blob/main/Prices_BTCUSDT.pkl?raw=true"
prices = pd.read_pickle(url).tolist()

# %% [markdown]
# * encontre o dia (valor do indice), correspondente ao menor valor
# * crie uma nova lista com o retorno diário dado pela formula abaixo
#
# $r_t = ln(\frac{preco_t}{preco_{t-1}})$
#
# $ln$ é o logaritmo natural e pode ser obtido pela função `np.log()`
# * encontre o dia (valor do indice), correspondente ao maior retorno

# %%
# para testar sua logica, limite o tamanho da lista prices
prices = prices[:6]

# %% [markdown]
# ____

# %% [markdown]
# 1. Construa um programa em Python que, repetitivamente, pede ao usuário nomes de pessoas (somente o primeiro nome da pessoa e sem acentos). Essa repetição se encerra quando o usuário digitar um nome "vazio" (o usuário digita ENTER sem nenhum nome). Cada um dos nomes deve obrigatoriamente ser transformado em letras maiúsculas e ser colocado numa lista denominada LISTA (a string vazia não deve ser colocada na lista!). O programa deve imprimir então a lista LISTA.
#
# 2. Em seguida, o programa deve, a partir da lista LISTA, gerar outra lista, denominada LISTA2, contendo somente os nomes que começam por letra consoante (sugestão: crie uma outra lista contendo as vogais maiúsculas do nosso alfabeto). Finalmente, deve imprimir a lista LISTA2.
#
# Critério de correção (valor total = 3,0):
# - apenas imprimiu LISTA (não conseguiu imprimir LISTA2)  --> abate 1,5
# - não tratou maiúscula/minúsculas --> abate 0,5
# - a string vazia foi para a lista --> abate 0,5
# - não há outros "meio-certo"
# - programas que não possam ser executados não serão corrigidos.
