# %% [markdown]
# ## tipos de variáveis

# %%
a = 10

# %%
b = -5.5

# %%
c = 'Hello'

# %%
d = False

# %%
type(a)

# %%
type(b)

# %%
type(c)

# %%
type(d)

# %% [markdown]
# ## operações

# %%
x = 10
y = 3

# %%
add = x + y
sub = x - y
mul = x * y
div = x / y
exp = x ** y
rem = x % y

# %%
print(add)
print(sub)
print(mul)
print(div)
print(exp)
print(rem)

# %%
10 % 3

# %%
10 // 3

# %%
10 / 3

# %%
dur = 173
qtd_anos = dur // 12
qtd_meses = dur % 12
print('o contrato tem a duração de', qtd_anos, 'anos e', qtd_meses, 'meses')

# %% [markdown]
# ## strings

# %%
escola = 'Fundação Getulio Vargas'

# %% [markdown]
# #### função len()

# %%
len(escola)

# %%
username = "abob"
size = len(username) # it is 9 
if size < 6:
    print("Please create an username with minimum of 5 characters")
else:
    print("Success!!")

# %% [markdown]
# #### função strip()

# %%
escola = '   Fundação Getulio Vargas '

# %%
len(escola)

# %%
escola.strip()

# %% [markdown]
# #### função replace()

# %%
escola = 'Fundacão Getúlio Vargas'

# %%
escola.replace('c', 'ç')

# %%
type("")

# %% [markdown]
# #### concatenação

# %%
n1 = 'Fundação '
n2 = 'Getúlio '
n3 = 'Vargas'
nota = 10

# %%
escola = n1 + n2 + n3

# %%
escola

# %%
# isso não vai funcionar....
n1 + n2 + n3 + ' é nota' + nota

# %%
n1 + n2 + n3 + ' é nota ' + str(nota)

# %%
float(10)

# %%
int(5.5)

# %% [markdown]
# #### extraindo um substring

# %%
n1, n2, n3

# %%
n1[1]

# %%
n1[3]

# %%
n1[2:5]

# %%
n1[-3]

# %%
n1[-6: -2]

# %%
n1, n2, n3

# %%
n1[0] + n2[0] + n3[0]

# %% [markdown]
# #### find()

# %%
escola = 'Fundação Getúlio Vargas'

# %%
escola.find('d')

# %%
escola.find('a')

# %% [markdown]
# #### lower(), upper(), capitalize()

# %%
escola.lower()

# %%
escola.upper()

# %%
escola.capitalize()
