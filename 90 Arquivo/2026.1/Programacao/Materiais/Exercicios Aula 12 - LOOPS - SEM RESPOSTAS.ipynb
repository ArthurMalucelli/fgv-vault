# %% [markdown]
# Queremos escrever um programa que produz a soma dos numeros de 1 até 1000 (inclusive).
#
# ```
# s = _(A)_
# for i in _(B)_:
#     s = s + _(C)_
# print('a soma de 1 até 1000 é', s)
# ```
#
#
# Selecione a(s) alternativa(s) correta(s) para preencher as lacunas _(A)_, _(B)_ e _(C)_:
#
# * `i, range(0, 1000), 1`
# * `0, range(0, 1001), i`
# * `0, range(1, 1001), i`
# * `0, range(0, 1000), i`
# * `0, range(1, 1001), s`
# * `0, range(0, 1000), 1`
# * `0, range(0, 1000), s`
# * `1, range(1000), i`
# * `s, range(0, 1001), i`
# * `1, range(0, 1000), 1`
# * `1, range(0, 1001), i`
#
# Obs: pode haver nenhuma, uma ou mais de uma resposta correta. Voce deverá assinalar todas as alternativas corretas para pontuar nessa questão. Não haverá meio-certo.

# %% [markdown]
# _____

# %% [markdown]
# Construa um programa em Python que calcule a soma 4/1 + 4/2 + 4/3 + ... + 4/888888. Você somará, portanto, exatamente 888888 parcelas.
#
# Informe sua resposta (a soma) no campo abaixo, com seis casas decimais após a vírgula (use vírgula e não ponto decimal). Você não precisa entregar o programa Python.
# Critério de correção (valor = 3,0)

# %% [markdown]
# ___

# %% [markdown]
# Construa um jogo, no qual voce precisa acertar uma soma. Apresente dois numeros inteiros aleatórios entre 0 e 10, e pergunte a soma. Se voce acertar, o programa deverá gerar novos números e uma pergunta. Encerre o programa quando voce errar, e ao final apresente quantas perguntas voce acertou.

# %% [markdown]
# ___

# %% [markdown]
# Construa um programa python que seja capaz de perguntar o nome completo de uma pessoa e então:
#
# a) Informar por quantos nomes o nome completo da pessoa é formado. Dica: conte quantos espaços há no nome completo!
#
# b) Informar quantas vogais o nome completo contém (lembrar que as vogais podem ser maiúsculas e minúsculas).
#
# c) Se houver mais de 6 vogais no nome completo, o programa deve perguntar à pessoa se ela gosta do seu primeiro nome.
#
# d) Se houver mais de 6 vogais no nome completo e a pessoa informar que não gosta do seu primeiro nome, o programa deve informar qual é esse primeiro nome não apreciado.
#
# Admitir que todo nome completo possui ao menos dois nomes, apenas um espaço entre os nomes, e que o usuário do programa não usará acentuação ao informar o seu nome completo.
#
# Cada item valerá 1,0 ponto desde que o programa python seja de fato capaz de realizar o solicitado. Não há meio-certo em cada item.
#
# Não serão corrigidos programas que não possam ser executados. Assim, se houver trechos problemáticos no programa, retire-os antes de copiar ao eClass.

# %% [markdown]
# -----

# %% [markdown]
# A palindrome is a word that is the same if you write backward and forward.
# Write a program that ask user for a word.
# Check if the word is a palindrome.
# If it is not, tell user what the word would be backwards
# Hint: use word[number] and word[-number] to compare the letters

# %% [markdown]
# ____

# %% [markdown]
# Escrever um programa que pergunta um valor inteiro positivo maior que 0, e o coloca na variável $n$.
#
# Em seguida apresenta na tela os elementos de uma matriz identidade de dimensão $n$.
#
# Por exemplo
#
# i)  se $n=3$, deverá ser apresentado:
#     100
#     010
#     001
#
# ii) se $n=5$, deverá ser apresentado:
#     10000
#     01000
#     00100
#     00010
#     00001
