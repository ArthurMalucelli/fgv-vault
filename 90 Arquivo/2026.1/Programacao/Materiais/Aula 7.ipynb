# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
b=10

# %%
print(b)
# Out:
# 10

# %%
print(a+b)
# Out:
# 15

# %%
c = "Hello"

# %%
print(c)
# Out:
# Hello

# %%
a + b
# Out:
# 15

# %%
x = a + b

# %%
x
# Out:
# 15

# %%
x = print(a + b)
# Out:
# 15

# %%
x

# %%
d = 0.5
print(d)
# Out:
# 0.5

# %%
r = 0.01
(1 + r)**10 - 1
# Out:
# 0.10462212541120453

# %% [markdown]
# ## Exercicio
# Se a = 10, b = 20, são catetos de um triangulo retângulo, qual o comprimento da hipotenusa?

# %%
a = 3
b = 4
c = (a**2 + b**2) ** (1/2)
print('Em um triangulo retangulo com catetos', a, ',', b, 'a hipotenusa é', c)
# Out:
# Em um triangulo retangulo com catetos 3 , 4 a hipotenusa é 5.0

# %%
2 < 5
# Out:
# True

# %%
4 > 10
# Out:
# False

# %%
a = 3

# %%
a == 3
# Out:
# True

# %%
z == 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 z == 3
#
# NameError: name 'z' is not defined

# %%
a != 3
