# %%
print(123)

# %%
print('123')

# %%
n = input('digite um numero:')
print('voce digitou', n)

# %%
int(n)+4

# %%
n = input('digite um numero:')
n = int(n)
print('voce digitou', n)

# %%
n = input('digite um numero:')
n = int(n)
n = n + 1
print('n agora tem o valor', n)

# %%
n = input('digite um numero n:')
n = float(n)
n = n / 3
print('n dividido por 3 é', n)

# %%
a = 5
b = 10
a + b

# %%
h = "Hello "
w = "World"
h + w

# %%
h + str(a)

# %%
4 != 4

# %%
resultado = input("Quanto é 2+2?")
resultado = int(resultado)
if resultado == 4:
    print("acertou")
else:
    print("errou")

# %%
meu_numero = 10

# %%
if, else, lambda, for, while, in, ...
