# %% [markdown]
# ## Exercícios

# %% [markdown]
# **Imprimir** (**apresentar**) a multiplicação entre 2020 e 2019

# %% [markdown]
# **Definir a variável x** como sendo a multiplicação entre 2020 e 2019

# %% [markdown]
# Pedir ao usuário um número e imprimir seu triplo<br>
# **Importante**: Quanto você recebe um dado pelo input, você recebe uma STRING (um texto)
# Para transformar o texto em um número, use int(variável)

# %% [markdown]
# Perguntar ao usuário 3 notas: P1, P2 e PF. Calcular a média ponderada final com pesos 30%, 35% e 35%.

# %% [markdown]
# Perguntar ao usuário 2 notas: P1, P2. P1, P2 e PF tem pesos 30%, 35% e 35%, respectivamente. Calcular a nota da PF necessaria para passar na disciplina.

# %% [markdown]
# Suponha que você sempre saia para comer pizza com os amigos.<br>
# Já que um de vocês sempre busca e leva todo mundo pra casa, vocês decidiram
# que ele/ela não precisa pagar os 10% da conta do restaurante.<br>
# Crie um programa que calcula o quanto cada um tem que pagar.
# Entradas:
# * valor total da conta (sem os 10%)
# * número de pessoas (incluindo você e o motorista)
