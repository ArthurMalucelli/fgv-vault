# %%
frase = "Mat eh viado pra caralho"
qtd = 0
for letra in frase:
    if letra == "a":
        qtd = qtd + 1
print(qtd)
# Out:
# 5

# %%
[1,2,3]
letra = [0]
type(letra)
# Out:
# list

# %%
"abcabc".find("b")
# Out:
# 1

# %%
-7 // 2
# Out:
# -4

# %%
7 // 2
# Out:
# 3
