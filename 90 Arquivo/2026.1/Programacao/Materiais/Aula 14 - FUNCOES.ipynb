# %%
lista = [1,2,3]
sum(lista)
# Out:
# 6

# %%
len(lista)
# Out:
# 3

# %%
sum(lista)/len(lista)
# Out:
# 2.0

# %%
def mean(l):
    return sum(l)/len(l)

# %%
mean(lista)
# Out:
# 2.0

# %%
lista2 = [-3, 0, 4, 10]

# %%
mean(lista2)
# Out:
# 2.75

# %%
def greet(nome):
    print('hello,', nome)

# %%
greet('John')
# Out:
# hello, John

# %%
greet('Mary')
# Out:
# hello, Mary

# %%
def f(x):
    return x**2

f(-4)
# Out:
# 16

# %%
def escreve_x_ao_quadrado(x):
    print(x**2)
    
escreve_x_ao_quadrado(-4)
# Out:
# 16

# %%
y = f(5)

# %%
print(y)
# Out:
# 25

# %%
z = escreve_x_ao_quadrado(5)
# Out:
# 25

# %%
print(z)
# Out:
# None

# %%
def g(x, y):
    m = (x + y)/2
    return m

g(-10, 5)
# Out:
# -2.5
