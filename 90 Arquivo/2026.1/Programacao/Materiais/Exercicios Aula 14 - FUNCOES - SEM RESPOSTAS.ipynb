# %% [markdown]
# Crie um programa que repedidamente pergunte ao usuário dois numeros, e uma opção entre `media_geometrica` ou `media_aritmetica`.
#
# Em seguida apresente o resultado da média selecionada.
#
# O programa deve encerrar quando o usuário digitar `encerrar` na inserção do primeiro número.
#
# DICA: Crie o programa sem a utilização de funções primeiro, depois mova os calculos de cada tipo de media para funções

# %% [markdown]
# ----

# %% [markdown]
# Ao escrevermos no Python a expressão c = a/b, corremos o risco de ocorrer erro, no caso de b ser zero. Construa então uma função divisao(a, b) que recebe como parâmetros dois números quaisquer a e b e que realiza a divisão, retornando o seguinte resultado:
# - se b = 0, retorna 999999
# - se b é diferente de 0, retorna o quociente a/b
#
# Não se preocupe em tratar o caso de a e b não serem números (vamos admitir que sejam).
# Construa também um programa para testar o uso da função divisao. O programa deve chamar a função divisao com exemplos nos dois casos (divisor igual a zero e divisor diferente de zero).
# ATENÇÃO: no corpo da função divisao, não deve haver nenhum comando print ou display.
#
#
# Critério de correção (valor total = 3,0):
# - não construiu uma função com def --> zero
# - não retorna os resultados para o programa chamador da função --> zero
# - não apresentou o programa de testes --> abate 1,0
# - não há outros "meio-certo"
# - programas que não possam ser executados não serão corrigidos.

# %% [markdown]
# ____

# %% [markdown]
# Exercise 4
#
# Write a function that returns (not prints!) a boolean variable (True/False) if a number is prime or not.

# %% [markdown]
# ____

# %% [markdown]
# Escreva o código Python que define uma função que recebe dois números como parâmetros. Se qualquer dos números for exatamente o dobro do outro, retorna (return) True. Se nenhum dos números for o dobro do outro, retorna False. Você não precisa se preocupar em detectar situações de erro por parte do usuário.
#
# Critérios de correção:
#
# programa Python com mensagens de erro não será corrigido
# * se houver qualquer comando print nessa resposta, recebe zero na questão
# * se não construir uma função para realizar o solicitado, recebe zero na questão
# * se a função não receber dois parâmetro de entrada, recebe zero na questão
# * se a função não usar o comando return com a resposta, recebe zero na questão
# * meio-certo apenas na situação de testar apenas um dos números para ver se é o dobro do outro
# * nos demais casos de erro, recebe 0,0 nesta questão

# %%
def dobro(x, y):
    if x == 2*y:
        return ("true")
    elif y == 2*x:
        return ("true")
    else:
        return ("false")

# %%
dobro(1 ,2)
# Out:
# 'true'

# %% [markdown]
# ____

# %% [markdown]
# Exercise 8
#
# You have a list of DVDs and needs to know how many discs are there:
# http://profalibania.com.br/python/dvdCollection.xlsx
# You know that:
# * a) simple = 1 disc
# * b) Special Edition = 2 discs
# * c) 3D = 2 discs
# * d) series = 6 discs
# * e) series - sitcom = 4 discs
#
# You have a file that contains a list of titles and their types.
# Create a function that read each type and return the quantity of discs
# Print the total number of discs.

# %% [markdown]
# ____

# %% [markdown]
# Escrever uma função que receba um argumento chamado pdi e retorne uma aliquota, segundo a descrição a seguir:
#
# Prazo de Investimento: Alíquota de IR
#
# * Até 180 dias: 22,50%
# * 181 até 360 dias: 20,00%
# * 361 até 720 dias: 17,50%
# * Acima de 720 dias: 15,00%
#
# A primeira e a ultima linha seguem abaixo. Voce deverá preencher com a logica interna da função:
# ```
# def get_aliquota(pdi):
#
#     <seu codigo>
#
#     return aliquota
# ```
# Obs:
# 1. indentar corretamente todo o codigo. Indentação incorreta anula questão
# 2. utilizar os nomes de variaveis pdi e aliquota para o argumento e valor de retorno
# 3. retornar o valor da aliquota em decimal. Por exemplo, se for 10% o valor de retorno deverá ser 0.1

# %% [markdown]
# ___

# %% [markdown]
# Contrua uma função denominada TESTANUM que testa se uma string é composta apenas
# por 0 a 9, vírgula e sinal de menos.
# Repare que exige vírgula (para funcionar no Brasil) e esta, se existir, pode
# estar em qualquer posição da string (mas não pode haver mais de uma vírgula!)
# Repare que aceita sinal de menos, mas somente ocupando a posição inicial
# da string.
# A função nada deve imprimir.
# Se o formato do número era correto, a função deve devolver, ao programa que a chamou, o número no formato float (com ponto decimal ao invés da vírgula).
# Se o formato do número era incorreto, a função deve devolver a string "erro".
#
#
# Critérios de correção:
# valor = 3,4
# * - se código não é executável: nada pontua
# * - se fez uma programa mas não uma função: nada pontua
# * - se houver print ou display dentro do corpo da função: nada pontua
# * - se permitiu o sinal "-" em outro local: perde 1,5
# * - se permitiu mais de uma vírgula: perde 1,5
# * - se não transformou vírgula em ponto: perde 1,0
# * - demais erros: nada pontua.
