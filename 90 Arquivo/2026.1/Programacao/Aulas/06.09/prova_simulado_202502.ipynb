# %% [markdown]
# **Questão 0 (identificação):**<br>
# Preencha seus dados na célula abaixo. Veja exemplo:
# ```
# # Nome: Carlos Drummond
# # Turma: AE1
# # Código: C00000000
# ```
#
# Importante:
# * não remover '#'
# * não remover nenhum caractere pré-preenchido, ou seja, completar com seus dados somente após o ':'
# * na Turma utilizar somente **AE1, AE2, AE3, AE4, AE5, AE6**

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 0 - NÃO DELETAR ESTA LINHA !!

# Nome:
# Turma:
# Código:

# %% [markdown]
# ---
#
#
# **Questão 1 (1 ponto):** <br>
#
# Considere que vendas é um dataframe com várias colunas, entre elas **"Ano"**, **"Região"** e **"Valor"**. <br>
# A coluna **"Ano"** contém um valor inteiro no conjunto {2026, 2027, 2028}.<br>
# **"Valor"** contém apenas números e a coluna **"Região"** contém texto.<br>
#
# Precisamos fazer um ajuste na previsão de vendas para 2026. Todos os valores para esse ano precisam ser reduzidos em 10\% <br>
# Exatamente duas das opções abaixo estão corretas. Assinale todas as alternativas corretas <br>
# (não tente rodar o código, porque vendas não está definido):
# ```
# a) vendas[vendas["Ano"]==2026, "Valor"] = vendas[vendas["Ano"]==2026, "Valor"] * 0.9
# b) vendas.loc[vendas["Ano"]==2026, "Valor"] *= 0.9
# c) vendas[vendas[Ano]=="2026"] = vendas[vendas[Ano]=="2026"] * 0.9
# d) vendas.loc[vendas["Ano"]==2026, "Valor"] = vendas.loc[vendas["Ano"]==2026, "Valor"] * 0.9
# e) vendas.loc["Ano"==2026, "Valor"] = vendas.loc["Ano"==2026, "Valor"] * 0.9
# ```
#
# CRITÉRIO DE CORREÇÃO (1,0):<br>
# não há pontuação parcial nessa questão

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 1 - NÃO DELETAR ESTA LINHA !!


# alternativa x porque....

# %% [markdown]
# ----
# **Questão 2 (2 pontos):** <br>
#
# Rodar o código abaixo para carregar o dataframe `times`
#
# ```
# import pandas as pd
#
# times = pd.DataFrame({'time': ['Palmeiras', 'Flamengo', 'Cruzeiro', 'Mirassol', 'Bahia', 'Botafogo', 'Fluminense'],
#                       'UF': ['SP', 'RJ', 'MG', 'SP', 'BA', 'RJ', 'RJ'],
#                       'jogos': [32, 32, 33, 33, 33, 33, 33],
#                       'pontos': [68, 68, 64, 59, 53, 52, 51]})
# ```
#
# Crie instruções para atualizar a tabela da seguinte forma :
# * A quantidade de jogos deve ser acrescida de 1
# * Todos os times de 'SP' ganharam (pontos devem ser acrescidos de 3)
# * Todos os times de 'RJ' empataram (pontos devem ser acrescidos de 1)
# * Os demais times mantem seus pontos inalterados
#
# \
# CRITÉRIO DE CORREÇÃO (2,0):
# * Cada instrução correta vale aproximadamente 0,67 pt (0,67 + 0,67 + 0,66 = 2,0). Não há pontuação parcial dentro de cada instrução.

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 2 - NÃO DELETAR ESTA LINHA !!

# %% [markdown]
# ---
# **Questão 3 (2 pontos):** <br>
#
# O valor do frete para os clientes da Dr. Paçoca depende do peso total do pedido em gramas (por exemplo, 3,5 kg = 3500g) e da localização deste cliente.
#
# O frete é **proporcional ao peso**: multiplique o peso em quilogramas (ou seja, `peso_em_gramas / 1000`) pela tarifa da faixa correspondente:
#
# * Se o peso for até 10.000g: R\$0,98 por quilo
# * Se o peso estiver entre 10.001g e 50.000g: R\$0,74 por quilo
# * Se o peso estiver entre 50.001g e 100.000g: R\$0,42 por quilo
# * Se o peso for acima de 100.000g: R\$100 fixo, independentemente do peso
#
# Exemplo de cálculo: um pedido de 3500g (3,5 kg) para SP custa `3.5 * 0.98 = R$3,43`.
#
# Adicional por estado:
# * Se o estado for SP ou PR: sem adicional
# * Se o estado for MG, RJ ou ES: o frete **dobra** — inclusive quando o peso ultrapassa 100.000g (nesse caso, R\$100 passa a R\$200)
# * Não há entregas para outros estados; se o usuário digitar qualquer UF fora das 5 acima, isso deve ser tratado como erro de entrada.
#
# Você deve criar um programa que:\
# a) receba do usuário o peso do pedido (valor inteiro em gramas) e o destino (sigla da UF)\
# b) valide as informações:\
#     - o peso deve ser um número inteiro (não pode conter caracteres não numéricos, nem ponto decimal)\
#     - o destino deve ser um dos cinco estados acima. Além disso, se o usuário digitar "sp" (minúsculas), o programa deve reconhecê-lo como SP.\
#     - Se houver erro, mostrar a mensagem `ERRO DE ENTRADA` e não calcular o frete.\
# c) caso não haja erros, apresente o valor do frete.
#
# **DICAS:**
# * `"123".isdigit()` retorna `True`; `"12.3".isdigit()` e `"abc".isdigit()` retornam `False`.
# * o método `.upper()` transforma `"sp"` em `"SP"`.
#
# \
# CRITÉRIO DE CORREÇÃO (2,0):\
# 1,0: o programa coletou os dados do usuário, validou as entradas (peso inteiro e UF válida) e realizou as transformações necessárias\
# 1,0: o programa calcula corretamente o frete em todos os cenários (todas as faixas de peso e todos os estados) e imprime o resultado\
#
# **OBS**: Não há pontuação parcial dentro de cada rubrica. Por exemplo, acertar o cálculo só para alguns estados ou algumas faixas de peso, e errar para os demais, não garante pontuação parcial: a 2ª rubrica recebe 0,0 pt ou 1,0 pt.

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 3 - NÃO DELETAR ESTA LINHA !!

# %% [markdown]
# ---
# **Questão 4 (2 pontos):** <br>
#
# Considere o arquivo `dataset_checkup_1000linhas.csv`, que contém informações de pacientes com as seguintes colunas:
#
# - `id`
# - `idade`
# - `peso`
# - `altura`
# - `fumante` (`"sim"` ou `"não"`)
# - `historico_familiar` (`"sim"` ou `"não"`, indicando se pai/mãe teve problema cardíaco)
# - `diabetes` (`"sim"` ou `"não"`)
# - `pressao_sistolica`
# - `pressao_diastolica`
#
# A recomendação de **checkup** deve seguir as regras abaixo (nesta ordem de prioridade):
#
# 1. Se `pressao_sistolica >= 140` **OU** `pressao_diastolica >= 90`, então **fazer checkup**.
# 2. Caso contrário, se `idade >= 50`, então **fazer checkup**.
# 3. Caso contrário, se `diabetes == "sim"` **OU** `historico_familiar == "sim"` **OU** `fumante == "sim"`, então **fazer checkup**.
# 4. Caso nenhuma das condições anteriores seja verdadeira, então **não precisa checkup**.
#
# <img src="arvore_decisao_checkup_v2.png" width="800">
#
# Monte um programa em Python que:
#
# 1. Carregue o dataset em um dataframe chamado `pacientes`.
# 2. Peça ao usuário para digitar um `id` de paciente (número inteiro). Você pode assumir que o usuário sempre digitará um número inteiro válido.
# 3. Verifique se o `id` existe no dataframe:
#    - Se **não existir**, apresente a mensagem: `Paciente não encontrado`.
#    - Se **existir**, selecione a linha correspondente e, usando as regras acima, apresente na tela o `id`, a `idade` e a recomendação final (`fazer checkup` ou `não precisa checkup`).
#
# **Exemplo de formato de saída** (siga exatamente este formato, inclusive o travessão `–`):
# `Paciente 123 (idade: 57) – Recomendação: fazer checkup`
#
# **Dicas:**
#
# Para carregar o dataframe `pacientes`:
# ```
# import pandas as pd
# pacientes = pd.read_csv("dataset_checkup_1000linhas.csv")
# ```
#
# *(Os arquivos `dataset_checkup_1000linhas.csv` e `arvore_decisao_checkup_v2.png` são fornecidos junto com esta prova e devem estar na mesma pasta do notebook.)*
#
# **CRITÉRIO DE CORREÇÃO (2,0):**
#
# 1,0 ponto: Leu corretamente o dataset, verificou a existência do id e tratou o caso "Paciente não encontrado".\
# 1,0 ponto: Aplicou corretamente TODAS as regras da árvore de decisão e exibiu a recomendação no formato pedido.

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 4 - NÃO DELETAR ESTA LINHA !!

# %% [markdown]
# ---
# **Questão 5 (3 pontos):** <br>
#
# Temos uma lista com registros de data/hora, em formato string, sendo que alguns deles somente contêm a data e não a hora. Veja um exemplo abaixo:
#
# ```
# ["2025-10-02 10:00", "2025-10-03", "2025-10-03 01:00", "2025-10-03 10:00", "2025-10-04 08:45", "2025-10-05"]
# ```
#
# Considere que todos os registros estão corretos e seguem somente um dos dois formatos:
# * `YYYY-MM-DD HH:MM`, quando há data e hora
# * `YYYY-MM-DD`, quando há somente a data
#
# Você deve construir um programa que, dada uma lista de strings nesse formato, imprima uma linha para cada elemento, escrevendo:<br>
# dia (número) + mês (por extenso) + ano (número) + a parte da hora/minuto, se houver.
# Por exemplo, para a lista acima, seu programa deve retornar:
#
# ```
# 2 de outubro de 2025 às 10 horas
# 3 de outubro de 2025
# 3 de outubro de 2025 à 1 hora
# 3 de outubro de 2025 às 10 horas
# 3 de outubro de 2025 às 8 horas e 45 minutos
# 5 de outubro de 2025
# ```
#
# Notar que:
# - Se a hora for igual a 1, escrever "à 1 hora".
# - Se a hora for diferente de 1, escrever "às X horas".
# - Se os minutos forem iguais a 0, não escrever a parte dos minutos.
# - Se os minutos forem iguais a 1, escrever "1 minuto".
# - Se os minutos forem maiores que 1, escrever "X minutos".
# - A parte dos minutos, quando existir, é ligada à parte da hora pela palavra "e". Ex.: `"2025-12-25 01:30"` deve gerar `25 de dezembro de 2025 à 1 hora e 30 minutos`.
#
# DICAS:
# * utilize a lista python: <br>
#     `meses_do_ano = ['janeiro', 'fevereiro', 'março', 'abril', 'maio', 'junho', 'julho', 'agosto','setembro', 'outubro', 'novembro', 'dezembro']`
# * `int('02')` retorna `2`
# * crie a lógica para processar um registro, depois a envolva num laço
# * a string pode ser montada na sequência: 1) data -> 2) data + hora (se houver) -> 3) data + hora + minuto (se houver), utilizando concatenação de strings
#
# \
# CRITÉRIO DE CORREÇÃO (3,0):\
# 0,5 ponto: Implementou um laço\
# 0,5 ponto: Separou a data da hora (se houver)\
# 1,0 ponto: Criou a lógica correta para distinguir registros com e sem hora\
# 1,0 ponto: Rearranjou os componentes para produzir a resposta final correta para cada registro
#
# **ATENÇÃO**: O programa deverá funcionar para qualquer lista com elementos no formato apresentado e com uma quantidade arbitrária de elementos — e não apenas para o exemplo informado.
