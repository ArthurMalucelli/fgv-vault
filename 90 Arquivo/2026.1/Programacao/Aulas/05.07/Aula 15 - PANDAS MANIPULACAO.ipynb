# %% [markdown]
# # ABRIR Aula 15 PANDAS MANIPULACAO.ipynb

# %%
# import pandas as pd
# url = "http://profalibania.com.br/python/olympicMedals2016.xlsx"
# df = pd.read_excel(url)

# %%
import pandas as pd
df = pd.read_pickle('olympicMedals2016.pkl')

# %% [markdown]
# ### dataframe

# %%
df
# Out:
#                   Country Short  Gold  Silver  Bronze
# 0          United States    USA    46      37      38
# 1          Great Britain    GBR    27      23      17
# 2                  China    CHN    26      18      26
# 3                 Russia    RUS    19      17      20
# 4                Germany    GER    17      10      15
# ..                    ...   ...   ...     ...     ...
# 81               Morocco    MAR     0       0       1
# 82               Nigeria    NGR     0       0       1
# 83              Portugal    POR     0       0       1
# 84   Trinidad and Tobago    TTO     0       0       1
# 85  United Arab Emirates    UAE     0       0       1
#
# [86 rows x 5 columns]

# %%
len(df)
# Out:
# 86

# %%
df.shape
# Out:
# (86, 5)

# %% [markdown]
# ### accessando uma coluna
# * indexação
# * fatiamento (slicing)

# %%
df['Country']

# %%
df[['Gold', 'Silver', 'Bronze']]

# %%
# () parantheses, paranthesis
# [] square brackets
# {} curly brackets

# %% [markdown]
# ### ordenação

# %%
df.sort_values('Country')

# %%
df

# %%
# df = df.sort_value('Country')

# %% [markdown]
# ### filtragem por valor
# * fatiamento logico

# %%
df[]

# %%
df[df['Gold']==0]

# %%
df[df['Gold']>0]

# %% [markdown]
# operadores lógicos: &, |, ~

# %% [markdown]
# ### outros fatiamentos
# * usando loc
# * usando iloc

# %%
df['Bronze']

# %%
df.loc[[1,2,3]]

# %%
df.loc[[1,2,3],['Short', 'Gold', 'Silver']]

# %%
df.loc[[1,2,3],['Short', 'Gold', 'Silver']]

# %%
df

# %%
df.iloc[[1,2,3], [1,2,3]]

# %%
df.iloc[1:4, 1:4]

# %% [markdown]
# ### consolidação de valores
# * estatisticas

# %%
df['Gold'].sum()

# %%
sum(df['Gold'])

# %%
# soma das medalhas dos paises que 
# tiveram mais do que 3 medalhas de ouro
df[df['Gold']>3]['Gold'].sum()

# %%
df[df['Gold']>3]['Gold'].sum()

# %%
df.loc[df['Gold']>3, 'Gold'].sum()

# %%
df['Gold'].mean()

# %%
# desvio padrão
df['Gold'].std()

# %%
# moda
df['Gold'].value_counts()

# %%
# df['Gold'].product()

# %%
df['Gold'].median()

# %%
df['Gold'].sum()

# %%
df[['Gold', 'Silver', 'Bronze']].sum(axis=1)

# %%
df

# %% [markdown]
# ### valores unicos

# %%
df['Gold'].unique()

# %%
# df['Gold'].value_counts().plot(kind='bar')

# %%
df.head(3)

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
Cell In[1], line 1
----> 1 df.tail()

NameError: name 'df' is not defined
# Out:
#   Cell In[2], line 1
#     ---------------------------------------------------------------------------
#                                                                                ^
# SyntaxError: invalid syntax
