# %% [markdown]
# ## ATENÇÃO:
# * Os códigos desenvolvidos devem servir para qualquer cenário, não apenas para o exemplo fornecido pelo exercício.
# * As soluções que apresentem dados de outras versões de prova serão desconsideradas e não receberão pontos.
# * não remover '#' das áreas de código
# * não remover nenhum caractere ou código pré-preenchido, ou seja, completar com seus dados somente após o ':'
# * Não é necessário renomear o arquivo
# * na Turma utilizar somente **AE1, AE2, AE3, AE4, AE5, AE6**
# ---

# %% [markdown]
# **Questão 0 (identificação):**<br>
# Preencha seus dados na célula abaixo. Veja exemplo:
# ```
# # Nome: Getulio Vargas
# # Turma: AE1
# # Código: C00000000
# ```

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 0 - NÃO DELETAR ESTA LINHA !!

# Nome:
# Turma:
# Código:

# %% [markdown]
# ## Questão 1 (1,0 ponto)
#
#
# Você quer fazer um jogo de perguntas e respostas em que o usuário possa escolher entre
# 1. pagar `R$10` por três chances, ou
# 2. `R$4` por tentativa
#
# No segundo caso, se ele tiver `R$40`, por exemplo, poderá tentar 10 vezes.
#
# Ambos os laços podem ser realizados com *for* ou *while*. Contudo, existe uma opção mais apropriada para cada caso.
#
# Entre *for* e *while*, qual dos comandos você usaria para a repetição das tentativas em cada um dos casos? Justifique sua resposta.
#
# **CRITÉRIO DE CORREÇÃO (1,0):** <br>
# Não há pontuação parcial nessa questão

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 1 - NÃO DELETAR ESTA LINHA !!

# %% [markdown]
# ## Questão 2 (1,0 ponto)
#
#
# ```
# import pandas as pd
# URL = "https://meusite.com.br/pedidos.xlsx"
# pedidos = pd.read_excel(URL)
#
# pedidos.loc[pedidos["Estado"] == "SP", "Preço unitário"] = pedidos["Preço unitário"] * 0.2
#
# print(pedidos.head(10))
#
# ```
# O que este programa faz?
#
# OBS: não tente rodar esse programa, pois a Internet está bloqueada.
#
# **CRITÉRIO DE CORREÇÃO (1,0):** <br>
# São tres blocos de instruções. Cada bloco vale 0,33 pt

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 2 - NÃO DELETAR ESTA LINHA !!

importa a planilha de excel pedidos.xlsx e a define como pedidos. Depois, localiza os pedidos onde a coluna estado esta "SP", e puxa o Preço Unitario de cada pedido, e os redefine com um desconto de 80%. Depois imprime os primeiros 10 pedidos do dataframe.
# Out:
#   Cell In[1], line 3
#     importa a planilha de excel pedidos.xlsx e a define como pedidos. Depois, localiza os pedidos onde a coluna estado esta "SP", e puxa o Preço Unitario de cada pedido, e os redefine com um desconto de 80%.
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Questão 3 (2,5 pontos)
# A Dr. Paçoca dará descontos para os clientes, dependendo do ESTADO e do VALOR total do pedido. O usuário irá informar o ESTADO, a QUANTIDADE e o PREÇO UNITÁRIO. O VALOR total do pedido é a QUANTIDADE vezes o PREÇO UNITÁRIO do produto.
#
# Se o ESTADO for "SP":\
# a) Se o VALOR do pedido for menor que 3000, desconto de 9%\
# b) Se o VALOR for maior ou igual a 3000 (inclusive), desconto de 6.5%
#
# Se o ESTADO for "RJ":\
# a) Se o VALOR for menor que 2600, desconto de 10%\
# b) Se o VALOR for maior ou igual a 2600 (inclusive), desconto de 8%"
#
# Para os demais estados:\
# a) Se o VALOR estiver entre 1000 (inclusive) e 1900 (inclusive), desconto de 8%.\
# b) Desconto de 6% para os demais
#
# Você deve criar um programa que:\
# a) receba do usuário o ESTADO, a QUANTIDADE e o PREÇO UNITÁRIO do produto\
# b) obtenha o desconto correspondente\
# c) apresente o VALOR original do pedido, o VALOR do pedido com o desconto e a diferença em Reais.
#
# Suponha que o usuário irá fornecer os dados corretamente.<br>
# Ou seja, o usuário sempre vai digitar o ESTADO com duas letras maisculas.<br>
# E os valores numéricos requisitados somente conterão números, sem letras e nenhum caractere especial.<br>
#
# \
# **CRITÉRIO DE CORREÇÃO (2,5):**\
# 1,5: o programa calculou os descontos corretamente\
# 1,0: o programa apresentou corretamente os tres valores solicitados.
#
# **OBS**: Não há pontuação parcial para cada uma das duas rubricas acima. Ou seja, acertar somente para um estado e errar para os demais não garante pontuação parcial. Da mesma forma, apresentação correta de somente um ou dois valores solicitados não garante pontuação parcial.

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 3 - NÃO DELETAR ESTA LINHA !!
estado = input("Estado:")
quantidade = int(input("Quantidade:"))
preço = int(input("Preço Unitario:"))
valor_original = preço * quantidade
if estado == "SP":
    if valor_original < 3000:
        desconto = 0.91
    else:
        desconto = 0.935
elif estado == "RJ":
    if valor_original < 2600:
        desconto = 0.9
    else:
        desconto = 0.92
else:
    if valor_original >= 1000 and valor_original <= 1900:
        desconto = 0.92
    else:
        desconto = 0.94
valor_final = valor_original * desconto
diff = valor_original - valor_final
print(f"O valor original do seu pedido é de R${valor_original}, após a aplicação do desconto, o valor final do seu pedido foi de R${valor_final}, com diferença de R${diff}")
# Out:
# Estado: 10
# Quantidade: 10
# Preço Unitario: 10
# O valor original do seu pedido é de R$100, após a aplicação do desconto, o valor final do seu pedido foi de R$94.0, com diferença de R$6.0

# %% [markdown]
# # Questão 4 (2,5 pontos)
#
# O arquivo carregado na célula abaixo possui uma lista de pedidos do Dr. Paçoca no ano de 2025, sendo que as linhas do mes de dezembro contém expectativas (de pedidos). E justamente nesse mes de dezembro, os preços unitários dos pedidos sofrerão um reajuste de `R$0,04`.
#
# A empresa deseja saber qual será a diferença no faturamento com e sem o reajuste.
#
# Para isso, crie um programa em que :\
# a) o pandas calcule o preço unitário de cada produto (coluna total / quantidade), e os inclua em uma nova coluna chamada `Preço Unitário`\
# b) o pandas troque o valor do preço unitário apenas para os pedidos do mês de dezembro (coluna Mês = mês informado)\
# c) o pandas calcule o novo total de cada pedido (preço unitário (reajustado) x quantidade) para todos os clientes\
# d) seja calculada e apresentada a diferença entre o total faturado original e o após o reajuste.
#
# Utilize as variáveis `reajuste` e `mes` conforme código abaixo.
# O programa deve funcionar para quaisquer valores informados nestas variáveis.
#
# **ATENÇÃO:** se você receber esta mensagem de alerta, ignore-a:
#
# ```
# <ipython-input-2-7f21c703d007>:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ```
#
# \
# **CRITÉRIO DE CORREÇÃO (2,5):**\
# 0,5 ponto: o programa calculou corretamente o preço unitário\
# 1,0 ponto: o programa filtra os pedidos e troca o valor unitário dos pedidos selecionados\
# 1,0 ponto: o programa calcula e apresenta o novo total dos pedidos e informa a diferença

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 4 - NÃO DELETAR ESTA LINHA !!

import pandas as pd
pedidos = pd.read_excel('pedidos.xlsx', index_col=0)
reajuste = 0.04
mes      = 12
pedidos["Preço Unitário"] = pedidos["Total"] / pedidos["Quantidade"]
total_pre = pedidos["Total"].sum()
pedidos.loc[pedidos["Mês"] == mes, "Preço Unitário"] -= reajuste
pedidos["Total"] = pedidos["Preço Unitário"] * pedidos["Quantidade"]
total_pos = pedidos["Total"].sum()
dif = total_pre - total_pos
print(f"Faturamento pré-reajuste: R${total_pre}")
print(f"Faturamento pós-reajuste: R${total_pos}")
print(f"Diferença = R${dif.round(2)}")
# Out:
# Faturamento pré-reajuste: R$2222362.02
# Faturamento pós-reajuste: R$2193968.26
# Diferença = R$28393.76

# %% [markdown]
# # Questão 5 (3 pontos)
#
# A Dr. Paçoca recebe as faturas dos distribuidores em formato de strings, com valores separados por uma hashtag (#):
#
# ```
# "97513423#1975.2#20251119"
# ```
#
# O primeiro item é o número da nota fiscal (ex: 97513423); o segundo é o valor recebido (ex: 1975.2); e o último é a data no formato de ANO+MES+DIA (ex: 20251119). Então, 20251119 é, na verdade 19/11/2025.
#
# O distribuidor pode enviar várias faturas em uma mesma lista:
# ```
# faturas = ["97513423#1975.2#20251119", "85999482#359.2#20250723",
#               "19548467#39584.3#20250805"]
# ```
#
# Escreva um programa que mostre a informação de cada fatura e o total dos valores. As faturas devem ser impressas no seguinte formato:
#
# **Data (formato dd/mm/aaa) - Valor recebido**
#
# No exemplo acima, o resultado do programa seria:\
# 19/11/2025 - 1975.2\
# 23/07/2025 - 359.2\
# 05/08/2025 - 39584.3\
# Total: 41918.70
#
# **CRITÉRIO DE CORREÇÃO (3,0):**\
# 1,0 ponto: o programa separa os itens de cada fatura\
# 1,0 ponto: o programa troca o formato das datas\
# 0,5 ponto: o programa imprime as informações segundo o modelo solicitado\
# 0,5 ponto: o programa calcula e apresenta o total das faturas
#
# **ATENÇÃO**: O programa deverá funcionar para qualquer lista que contenha elementos no formato apresentado, e com uma quantidade arbitrária de elementos - e não apenas para o exemplo informado.

# %%
# ESPAÇO PARA RESPOSTA DA QUESTAO 5 - NÃO DELETAR ESTA LINHA !!
faturas = ["97513423#1975.2#20251119", "85999482#359.2#20250723",
              "19548467#39584.3#20250805"]
total = 0
for i in faturas:
    item = i.split("#")
    numero = item[0]
    valor = item[1]
    data = item [2]
    total += float(valor)
    for i in data:
        ano = data[0:4]
        mes = data[4:6]
        dia = data[6:8]
    print(f"{dia}/{mes}/{ano} - {valor}")
print(f"Total: {total}")
# Out:
# 19/11/2025 - 1975.2
# 23/07/2025 - 359.2
# 05/08/2025 - 39584.3
# Total: 41918.700000000004
